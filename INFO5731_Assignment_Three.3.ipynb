# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreshtaP/-Shreshta_INFO5731_-Fall2021/blob/main/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as the 500 reviews (abstracts, or tweets).

# %%
# Write your code here
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (95.0.4638.69-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 57 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (35.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %%
from selenium import webdriver1
options = webdriver1.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import timezone

DRV = webdriver.Chrome('chromedriver',options=options)
url_link = 'https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3' 
title_array = []
review_array = []
DRV.get(link) 
for num in range(4):
  DRV.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  Titlelists = DRV.find_elements(By.CLASS_NAME, "title")
  Reviewslist = DRV.find_elements(By.CLASS_NAME, "text") 
for ele, sub_ele in zip(Titlelist, Reviewslist):
  #appending title and review arrays
      title_arr.append((ele.text).replace('\n','')) 
      review_arr.append(sub_ele.text)
df1 = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("The length of Data frame is {0}".format(len(df)))
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# Data frame length is 125
#                                                  Title                                             Review
# 0                                           Next Phase
# 1            Shang-Chi and the Legend of the Ten Rings
# 2                                              Bus Boy
# 3                               Precious ... ten times  Of course I am just riffing off, teasing and m...
# 4                                                 Wow!  I was not expecting that, I had visions of a f...
# ..                                                 ...                                                ...
# 120               A Chinese cuisine with Michelin star  Unlogical story plot. Luckily actors performan...
# 121          best standalone marvel film since ragnork  Marvel is back to its root with this one it is...
# 122                                          Enjoyable  Usually, MCU movies are forgotten as soon as I...
# 123             Easily the best Superhero Film of 2021
# 124  THE CINEMA WAS BUZZING. WHAT A CINEMATIC EXPER...  The Cinema Was On Fire, I think It was Partly ...
#
# [125 rows x 2 columns]

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
import re
from nltk.stem import PorterStemmer
from textblob import Word
from textblob import TextBlob

nltk.download('Thewordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
df['After removing noise'] = df['Review'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

     #removing punctuation
df['removing punctuation'] = df['After removing noise'].str.replace('[^\w\s]','')

     #removal of numbers
df['removal of numbers'] = df['removing punctuation'].str.replace('\d+', '')

     #removing stopwods
no_of_stop_word = stopwords.words('english')
df['Removal of Stopwords'] = df['removal of numbers'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_word))

     #Lower Casing
df['Lower casing'] = df['Removal of Stopwords'].apply(lambda x: " ".join(x.lower() for x in x.split()))

     #Stemming
st = PorterStemmer()
df['Stemming'] = df['Lower casing'].apply(lambda x: " ".join([st.stem(word) for word in x]))

    #Lemmatization
 
df['Lemmatization'] = df['Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

final_df = df 
df.to_csv('reviwes.csv',index=False)

# %%
nltk.download('punkt')
import itertools
given_list_of_words = []
for i in df['Lower casing']:
  list_of_words.append(nltk.tokenize.word_tokenize(i))
NoofWords = [i for i in list_of_words if i != []]
Afterlooping = list(itertools.chain.from_iterable(Words))
#N-grams (N=3 -> Trigrams)
fd = nltk.FreqDist(nltk.trigrams(looping))
fd.most_common()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(('shang', 'chi', 'legend'), 43),
#  (('chi', 'legend', 'ten'), 40),
#  (('legend', 'ten', 'rings'), 40),
#  (('marvel', 'cinematic', 'universe'), 23),
#  (('destin', 'daniel', 'cretton'), 21),
#  (('the', 'ten', 'rings'), 15),
#  (('meng', 'er', 'zhang'), 14),
#  (('director', 'destin', 'daniel'), 11),
#  (('crouching', 'tiger', 'hidden'), 11),
#  (('tiger', 'hidden', 'dragon'), 11),
#  (('tony', 'chiu', 'wai'), 10),
#  (('chiu', 'wai', 'leung'), 10),
#  (('shang', 'chi', 'simu'), 7),
#  (('chi', 'simu', 'liu'), 7),
#  (('friend', 'katy', 'awkwafina'), 6),
#  (('chinese', 'martial', 'arts'), 5),
#  (('action', 'set', 'pieces'), 5),
#  (('shang', 'chi', 'the'), 5),
#  (('legend', 'the', 'ten'), 5),
#  (('film', 'shang', 'chi'), 5),
#  (('shang', 'chi', 'father'), 5),
#  (('martial', 'arts', 'film'), 5),
#  (('shaun', 'simu', 'liu'), 4),
#  (('the', 'marvel', 'cinematic'), 4),
#  (('the', 'fight', 'scenes'), 4),
#  (('ten', 'rings', 'organization'), 4),
#  (('shaun', 'shang', 'chi'), 4),
#  (('say', 'shang', 'chi'), 4),
#  (('hand', 'hand', 'combat'), 4),
#  (('overall', 'shang', 'chi'), 4),
#  (('tony', 'leung', 'michelle'), 4),
#  (('leung', 'michelle', 'yeoh'), 4),
#  (('crazy', 'rich', 'asians'), 4),
#  (('best', 'friend', 'katy'), 4),
#  (('chi', 'the', 'legend'), 4),
#  (('the', 'legend', 'the'), 4),
#  (('name', 'shang', 'chi'), 4),
#  (('the', 'visual', 'effects'), 4),
#  (('legend', 'of', 'the'), 4),
#  (('of', 'the', 'ten'), 4),
#  (('shang', 'chi', 'shaun'), 4),
#  (('short', 'term', 'just'), 4),
#  (('term', 'just', 'mercy'), 4),
#  (('powerful', 'ten', 'rings'), 3),
#  (('the', 'special', 'effects'), 3),
#  (('mcu', 'shang', 'chi'), 3),
#  (('ten', 'rings', 'i'), 3),
#  (('i', 'say', 'shang'), 3),
#  (('stand', 'alone', 'film'), 3),
#  (('katy', 'awkwafina', 'when'), 3),
#  (('xu', 'wenwu', 'tony'), 3),
#  (('simu', 'liu', 'lead'), 3),
#  (('plays', 'shang', 'chi'), 3),
#  (('best', 'marvel', 'movie'), 3),
#  (('movie', 'shang', 'chi'), 3),
#  (('story', 'shang', 'chi'), 3),
#  (('daniel', 'cretton', 'just'), 3),
#  (('cretton', 'just', 'mercy'), 3),
#  (('awkwafina', 'crazy', 'rich'), 3),
#  (('ten', 'rings', 'one'), 3),
#  (('forced', 'face', 'past'), 3),
#  (('father', 'xu', 'wenwu'), 3),
#  (('seen', 'big', 'screen'), 3),
#  (('i', 'loved', 'well'), 3),
#  (('see', 'shang', 'chi'), 3),
#  (('superhero', 'origin', 'story'), 3),
#  (('i', 'really', 'enjoyed'), 3),
#  (('this', 'film', 'also'), 3),
#  (('shang', 'chi', 'and'), 3),
#  (('chi', 'and', 'the'), 3),
#  (('and', 'the', 'legend'), 3),
#  (('the', 'legend', 'of'), 3),
#  (('cretton', 'short', 'term'), 3),
#  (('one', 'best', 'origin'), 3),
#  (('simu', 'liu', 'fantastic'), 3),
#  (('it', 'also', 'nice'), 2),
#  (('mid', 'credit', 'scene'), 2),
#  (('well', 'done', 'i'), 2),
#  (('i', 'expecting', 'i'), 2),
#  (('start', 'finish', 'i'), 2),
#  (('san', 'francisco', 'bus'), 2),
#  (('engaging', 'action', 'scenes'), 2),
#  (('there', 'also', 'quite'), 2),
#  (('shang', 'chi', 'liu'), 2),
#  (('martial', 'arts', 'films'), 2),
#  (('wenwu', 'tony', 'leung'), 2),
#  (('sean', 'shang', 'chi'), 2),
#  (('shang', 'chi', 'marvel'), 2),
#  (('good', 'fight', 'scenes'), 2),
#  (('best', 'fighting', 'mcu'), 2),
#  (('lol', 'i', 'stupid'), 2),
#  (('i', 'stupid', 'sometimes'), 2),
#  (('superhero', 'shang', 'chi'), 2),
#  (('played', 'ben', 'kingsley'), 2),
#  (('martial', 'arts', 'movie'), 2),
#  (('it', 'truly', 'unique'), 2),
#  (('mostly', 'asian', 'cast'), 2),
#  (('one', 'best', 'marvel'), 2),
#  (('best', 'marvel', 'films'), 2),
#  (('films', 'shang', 'chi'), 2),
#  (('ten', 'rings', 'action'), 2),
#  (('shang', 'chi', 'master'), 2),
#  (('master', 'kung', 'fu'), 2),
#  (('kung', 'fu', 'he'), 2),
#  (('involving', 'ten', 'rings'), 2),
#  (('i', 'admit', 'i'), 2),
#  (('i', 'strongly', 'recommend'), 2),
#  (('world', 'asian', 'culture'), 2),
#  (('previous', 'mcu', 'film'), 2),
#  (('black', 'widow', 'shang'), 2),
#  (('widow', 'shang', 'chi'), 2),
#  (('played', 'simu', 'liu'), 2),
#  (('simu', 'liu', 'and'), 2),
#  (('called', 'ten', 'rings'), 2),
#  (('father', 'tony', 'leung'), 2),
#  (('shang', 'chi', 'katy'), 2),
#  (('simu', 'liu', 'great'), 2),
#  (('friend', 'meng', 'er'), 2),
#  (('the', 'action', 'sequences'), 2),
#  (('ten', 'rings', 'yet'), 2),
#  (('rings', 'yet', 'another'), 2),
#  (('shang', 'chi', 'quite'), 2),
#  (('marvel', 'film', 'yet'), 2),
#  (('shang', 'chi', 'big'), 2),
#  (('chi', 'big', 'screen'), 2),
#  (('stories', 'shang', 'chi'), 2),
#  (('shang', 'chi', 'new'), 2),
#  (('shang', 'chi', 'it'), 2),
#  (('forced', 'confront', 'past'), 2),
#  (('shang', 'chi', 'another'), 2),
#  (('felt', 'like', 'i'), 2),
#  (('since', 'captain', 'marvel'), 2),
#  (('lives', 'san', 'francisco'), 2),
#  (('wenwu', 'tony', 'chiu'), 2),
#  (('trevor', 'slattery', 'ben'), 2),
#  (('slattery', 'ben', 'kingsley'), 2),
#  (('ben', 'kingsley', 'iron'), 2),
#  (('kingsley', 'iron', 'man'), 2),
#  (('ten', 'rings', 'stars'), 2),
#  (('stars', 'simu', 'liu'), 2),
#  (('liu', 'lead', 'role'), 2),
#  (('liu', 'shang', 'chi'), 2),
#  (('film', 'best', 'action'), 2),
#  (('er', 'zhang', 'xialing'), 2),
#  (('shang', 'chi', 'feels'), 2),
#  (('chi', 'feels', 'like'), 2),
#  (('like', 'marvel', 'movie'), 2),
#  (('lower', 'level', 'character'), 2),
#  (('movies', 'shang', 'chi'), 2),
#  (('ten', 'rings', 'movie'), 2),
#  (('the', 'storyline', 'movie'), 2),
#  (('follows', 'young', 'man'), 2),
#  (('michelle', 'yeoh', 'crouching'), 2),
#  (('yeoh', 'crouching', 'tiger'), 2),
#  (('movie', 'way', 'better'), 2),
#  (('bringing', 'martial', 'arts'), 2),
#  (('martial', 'arts', 'franchise'), 2),
#  (('breath', 'fresh', 'air'), 2),
#  (('chi', 'legend', 'tens'), 2),
#  (('legend', 'tens', 'rings'), 2),
#  (('tens', 'rings', 'easily'), 2),
#  (('rings', 'easily', 'top'), 2),
#  (('easily', 'top', 'origin'), 2),
#  (('top', 'origin', 'films'), 2),
#  (('origin', 'films', 'franchise'), 2),
#  (('films', 'franchise', 'given'), 2),
#  (('franchise', 'given', 'us'), 2),
#  (('given', 'us', 'one'), 2),
#  (('simu', 'liu', 'plays'), 2),
#  (('liu', 'plays', 'shang'), 2),
#  (('shang', 'chi', 'really'), 2),
#  (('character', 'shang', 'chi'), 2),
#  (('really', 'well', 'done'), 2),
#  (('i', 'feel', 'like'), 2),
#  (('i', 'thought', 'really'), 2),
#  (('first', 'act', 'film'), 2),
#  (('role', 'american', 'film'), 2),
#  (('the', 'final', 'act'), 2),
#  (('cinematic', 'universe', 'it'), 2),
#  (('fun', 'shang', 'chi'), 2),
#  (('actor', 'simu', 'liu'), 2),
#  (('marvel', 'universe', 'the'), 2),
#  (('one', 'better', 'films'), 2),
#  (('chi', 'father', 'xu'), 2),
#  (('choreographed', 'martial', 'arts'), 2),
#  (('first', 'iron', 'man'), 2),
#  (('comic', 'book', 'character'), 2),
#  (('would', 'look', 'like'), 2),
#  (('the', 'action', 'scenes'), 2),
#  (('especially', 'simu', 'liu'), 2),
#  (('marvel', 'projects', 'the'), 2),
#  (('best', 'action', 'sequences'), 2),
#  (('the', 'fight', 'choreography'), 2),
#  (('joel', 'p', 'west'), 2),
#  (('like', 'black', 'panther'), 2),
#  (('black', 'panther', 'african'), 2),
#  (('panther', 'african', 'culture'), 2),
#  (('action', 'movie', 'great'), 2),
#  (('world', 'the', 'film'), 2),
#  (('mandarin', 'tony', 'leung'), 2),
#  (('tony', 'leung', 'chiu'), 2),
#  (('leung', 'chiu', 'wai'), 2),
#  (('the', 'fighting', 'choreography'), 2),
#  (('steals', 'show', 'every'), 2),
#  (('love', 'shang', 'chi'), 2),
#  (('excited', 'see', 'shang'), 2),
#  (('asian', 'american', 'superhero'), 2),
#  (('two', 'post', 'credits'), 2),
#  (('post', 'credits', 'scenes'), 2),
#  (('i', 'give', 'shang'), 2),
#  (('give', 'shang', 'chi'), 2),
#  (('i', 'ever', 'seen'), 2),
#  (('simu', 'liu', 'perfect'), 2),
#  (('the', 'last', 'airbender'), 2),
#  (('come', 'expect', 'marvel'), 2),
#  (('the', 'action', 'great'), 2),
#  (('i', 'certainly', 'see'), 2),
#  (('actors', 'simu', 'liu'), 2),
#  (('also', 'feels', 'like'), 2),
#  (('film', 'in', 'fact'), 2),
#  (('in', 'fact', 'i'), 2),
#  (('san', 'francisco', 'parks'), 2),
#  (('francisco', 'parks', 'cars'), 2),
#  (('parks', 'cars', 'living'), 2),
#  (('real', 'name', 'shang'), 2),
#  (('leader', 'ten', 'rings'), 2),
#  (('shang', 'chi', 'world'), 2),
#  (('cinematic', 'universe', 'the'), 2),
#  (('ying', 'nan', 'florian'), 2),
#  (('nan', 'florian', 'munteanu'), 2),
#  (('must', 'watch', 'marvel'), 2),
#  (('watch', 'biggest', 'screen'), 2),
#  (('biggest', 'screen', 'possible'), 2),
#  (('marvel', 'super', 'hero'), 2),
#  (('deserves', 'seen', 'big'), 2),
#  (('writer', 'director', 'destin'), 2),
#  (('newcomer', 'simu', 'liu'), 2),
#  (('simu', 'liu', 'kim'), 2),
#  (('michelle', 'yeoh', 'shang'), 2),
#  (('yeoh', 'shang', 'chi'), 2),
#  (('shang', 'chi', 'aunt'), 2),
#  (('katy', 'meng', 'er'), 2),
#  (('and', 'tony', 'leung'), 2),
#  (('tony', 'leung', 'in'), 2),
#  (('iron', 'man', 'films'), 2),
#  (('game', 'changer', 'also'), 2),
#  (('daniel', 'cretton', 'short'), 2),
#  (('good', 'character', 'development'), 2),
#  (('like', 'iron', 'man'), 2),
#  (('ten', 'rings', 'marks'), 2),
#  (('father', 'shang', 'chi'), 2),
#  (('incredible', 'martial', 'arts'), 2),
#  (('ten', 'rings', 'far'), 2),
#  (('recommend', 'shang', 'chi'), 2),
#  (('cinematic', 'universe', 'mcu'), 2),
#  (('shang', 'chi', 'run'), 2),
#  (('chi', 'run', 'away'), 2),
#  (('mother', 'li', 'fala'), 2),
#  (('li', 'fala', 'chen'), 2),
#  (('sister', 'xialing', 'meng'), 2),
#  (('xialing', 'meng', 'er'), 2),
#  (('although', 'shang', 'chi'), 2),
#  (('mulan', 'shang', 'chi'), 2),
#  (('martial', 'arts', 'fight'), 2),
#  (('arts', 'fight', 'scenes'), 2),
#  (('movies', 'like', 'crouching'), 2),
#  (('like', 'crouching', 'tiger'), 2),
#  (('action', 'packed', 'fun'), 2),
#  (('best', 'origin', 'films'), 2),
#  (('the', 'acting', 'good'), 2),
#  (('good', 'special', 'effects'), 2),
#  (('li', 'played', 'fala'), 2),
#  (('played', 'fala', 'chen'), 2),
#  (('in', 'mood', 'love'), 2),
#  (('superb', 'martial', 'arts'), 2),
#  (('bus', 'fight', 'scene'), 2),
#  (('scene', 'one', 'best'), 2),
#  (('best', 'action', 'scenes'), 2),
#  (('i', 'say', 'i'), 2),
#  (('i', 'felt', 'like'), 2),
#  (('ten', 'rings', 'follows'), 2),
#  (('shang', 'chi', 'one'), 2),
#  (('best', 'fight', 'scenes'), 2),
#  (('fala', 'chen', 'also'), 2),
#  (('the', 'martial', 'arts'), 2),
#  (('closing', 'credits', 'i'), 2),
#  (('shang', 'chi', 'epic'), 2),
#  (('wai', 'leung', 'also'), 2),
#  (('fighting', 'styles', 'well'), 2),
#  (('scenes', 'characters', 'fight'), 2),
#  (('film', 'the', 'visual'), 2),
#  (('the', 'acting', 'well'), 2),
#  (('acting', 'well', 'done'), 2),
#  (('shang', 'chi', 'also'), 2),
#  (('the', 'first', 'act'), 2),
#  (('well', 'written', 'characters'), 2),
#  (('i', 'really', 'looking'), 2),
#  (('really', 'looking', 'forward'), 2),
#  (('good', 'martial', 'arts'), 2),
#  (('cameo', 'absolutely', 'slays'), 2),
#  (('future', 'films', 'the'), 2),
#  (('great', 'fighting', 'scenes'), 2),
#  (('of', 'course', 'i'), 1),
#  (('course', 'i', 'riffing'), 1),
#  (('i', 'riffing', 'teasing'), 1),
#  (('riffing', 'teasing', 'making'), 1),
#  (('teasing', 'making', 'fun'), 1),
#  (('making', 'fun', 'certain'), 1),
#  (('fun', 'certain', 'things'), 1),
#  (('certain', 'things', 'summary'), 1),
#  (('things', 'summary', 'line'), 1),
#  (('summary', 'line', 'though'), 1),
#  (('line', 'though', 'truth'), 1),
#  (('though', 'truth', 'especially'), 1),
#  (('truth', 'especially', 'consider'), 1),
#  (('especially', 'consider', 'last'), 1),
#  (('consider', 'last', 'third'), 1),
#  (('last', 'third', 'movie'), 1),
#  (('third', 'movie', 'quite'), 1),
#  (('movie', 'quite', 'fantastical'), 1),
#  (('quite', 'fantastical', 'pun'), 1),
#  (('fantastical', 'pun', 'intended'), 1),
#  (('pun', 'intended', 'but'), 1),
#  (('intended', 'but', 'much'), 1),
#  (('but', 'much', 'and'), 1),
#  (('much', 'and', 'may'), 1),
#  (('and', 'may', 'seen'), 1),
#  (('may', 'seen', 'bus'), 1),
#  (('seen', 'bus', 'scene'), 1),
#  (('bus', 'scene', 'already'), 1),
#  (('scene', 'already', 'i'), 1),
#  (('already', 'i', 'imagine'), 1),
#  (('i', 'imagine', 'many'), 1),
#  (('imagine', 'many', 'times'), 1),
#  (('many', 'times', 'still'), 1),
#  (('times', 'still', 'quite'), 1),
#  (('still', 'quite', 'highlight'), 1),
#  (('quite', 'highlight', 'works'), 1),
#  (('highlight', 'works', 'wonders'), 1),
#  (('works', 'wonders', 'because'), 1),
#  (('wonders', 'because', 'even'), 1),
#  (('because', 'even', 'trailer'), 1),
#  (('even', 'trailer', 'teaser'), 1),
#  (('trailer', 'teaser', 'revealed'), 1),
#  (('teaser', 'revealed', 'as'), 1),
#  (('revealed', 'as', 'plot'), 1),
#  (('as', 'plot', 'characters'), 1),
#  (('plot', 'characters', 'movie'), 1),
#  (('characters', 'movie', 'i'), 1),
#  (('movie', 'i', 'able'), 1),
#  (('i', 'able', 'watch'), 1),
#  (('able', 'watch', 'imax'), 1),
#  (('watch', 'imax', 'screen'), 1),
#  (('imax', 'screen', 'let'), 1),
#  (('screen', 'let', 'tell'), 1),
#  (('let', 'tell', 'wow'), 1),
#  (('tell', 'wow', 'but'), 1),
#  (('wow', 'but', 'also'), 1),
#  (('but', 'also', 'wow'), 1),
#  (('also', 'wow', 'much'), 1),
#  (('wow', 'much', 'respect'), 1),
#  (('much', 'respect', 'marvel'), 1),
#  (('respect', 'marvel', 'feige'), 1),
#  (('marvel', 'feige', 'anyone'), 1),
#  (('feige', 'anyone', 'involved'), 1),
#  (('anyone', 'involved', 'dared'), 1),
#  (('involved', 'dared', 'make'), 1),
#  (('dared', 'make', 'first'), 1),
#  (('make', 'first', 'ten'), 1),
#  (('first', 'ten', 'minutes'), 1),
#  (('ten', 'minutes', 'chinese'), 1),
#  (('minutes', 'chinese', 'and'), 1),
#  (('chinese', 'and', 'throwing'), 1),
#  (('and', 'throwing', 'lot'), 1),
#  (('throwing', 'lot', 'chinese'), 1),
#  (('lot', 'chinese', 'terms'), 1),
#  (('chinese', 'terms', 'slang'), 1),
#  (('terms', 'slang', 'well'), 1),
#  (('slang', 'well', 'throughout'), 1),
#  (('well', 'throughout', 'that'), 1),
#  (('throughout', 'that', 'gives'), 1),
#  (('that', 'gives', 'touch'), 1),
#  (('gives', 'touch', 'authenticity'), 1),
#  (('touch', 'authenticity', 'how'), 1),
#  (('authenticity', 'how', 'immigrants'), 1),
#  (('how', 'immigrants', 'america'), 1),
#  (('immigrants', 'america', 'anywhere'), 1),
#  (('america', 'anywhere', 'else'), 1),
#  (('anywhere', 'else', 'world'), 1),
#  (('else', 'world', 'grew'), 1),
#  (('world', 'grew', 'i'), 1),
#  (('grew', 'i', 'greek'), 1),
#  (('i', 'greek', 'german'), 1),
#  (('greek', 'german', 'english'), 1),
#  (('german', 'english', 'it'), 1),
#  (('english', 'it', 'also'), 1),
#  (('also', 'nice', 'i'), 1),
#  (('nice', 'i', 'prone'), 1),
#  (('i', 'prone', 'sarcastic'), 1),
#  (('prone', 'sarcastic', 'i'), 1),
#  (('sarcastic', 'i', 'really'), 1),
#  (('i', 'really', 'think'), 1),
#  (('really', 'think', 'good'), 1),
#  (('think', 'good', 'thing'), 1),
#  (('good', 'thing', 'major'), 1),
#  (('thing', 'major', 'big'), 1),
#  (('major', 'big', 'representation'), 1),
#  (('big', 'representation', 'especially'), 1),
#  (('representation', 'especially', 'nowadays'), 1),
#  (('especially', 'nowadays', 'anti'), 1),
#  (('nowadays', 'anti', 'asian'), 1),
#  (('anti', 'asian', 'hate'), 1),
#  (('asian', 'hate', 'crime'), 1),
#  (('hate', 'crime', 'rising'), 1),
#  (('crime', 'rising', 'all'), 1),
#  (('rising', 'all', 'people'), 1),
#  (('all', 'people', 'blaming'), 1),
#  (('people', 'blaming', 'china'), 1),
#  (('blaming', 'china', 'people'), 1),
#  (('china', 'people', 'china'), 1),
#  (('people', 'china', 'virus'), 1),
#  (('china', 'virus', 'movie'), 1),
#  (('virus', 'movie', 'topic'), 1),
#  (('movie', 'topic', 'entertainment'), 1),
#  (('topic', 'entertainment', 'every'), 1),
#  (('entertainment', 'every', 'promo'), 1),
#  (('every', 'promo', 'interview'), 1),
#  (('promo', 'interview', 'actors'), 1),
#  (('interview', 'actors', 'involved'), 1),
#  (('actors', 'involved', 'something'), 1),
#  (('involved', 'something', 'mentioned'), 1),
#  (('something', 'mentioned', 'good'), 1),
#  (('mentioned', 'good', 'good'), 1),
#  (('good', 'good', 'us'), 1),
#  (('good', 'us', 'made'), 1),
#  (('us', 'made', 'i'), 1),
#  (('made', 'i', 'bit'), 1),
#  (('i', 'bit', 'biased'), 1),
#  (('bit', 'biased', 'comes'), 1),
#  (('biased', 'comes', 'mcu'), 1),
#  (('comes', 'mcu', 'get'), 1),
#  (('mcu', 'get', 'pure'), 1),
#  (('get', 'pure', 'theatrical'), 1),
#  (('pure', 'theatrical', 'release'), 1),
#  (('theatrical', 'release', 'instead'), 1),
#  (('release', 'instead', 'black'), 1),
#  (('instead', 'black', 'widow'), 1),
#  (('black', 'widow', 'treatment'), 1),
#  (('widow', 'treatment', 'also'), 1),
#  (('treatment', 'also', 'available'), 1),
#  (('also', 'available', 'disney'), 1),
#  (('available', 'disney', 'plus'), 1),
#  (('disney', 'plus', 'cinemas'), 1),
#  (('plus', 'cinemas', 'time'), 1),
#  (('cinemas', 'time', 'so'), 1),
#  (('time', 'so', 'issue'), 1),
#  (('so', 'issue', 'comes'), 1),
#  (('issue', 'comes', 'and'), 1),
#  (('comes', 'and', 'watch'), 1),
#  (('and', 'watch', 'big'), 1),
#  (('watch', 'big', 'screen'), 1),
#  (('big', 'screen', 'dissapointed'), 1),
#  (('screen', 'dissapointed', 'now'), 1),
#  (('dissapointed', 'now', 'waiting'), 1),
#  (('now', 'waiting', 'stuff'), 1),
#  (('waiting', 'stuff', 'drop'), 1),
#  (('stuff', 'drop', 'especially'), 1),
#  (('drop', 'especially', 'mid'), 1),
#  (('especially', 'mid', 'credit'), 1),
#  (('credit', 'scene', 'tease'), 1),
#  (('scene', 'tease', 'credits'), 1),
#  (('tease', 'credits', 'scene'), 1),
#  (('credits', 'scene', 'might'), 1),
#  (('scene', 'might', 'also'), 1),
#  (('might', 'also', 'hint'), 1),
#  (('also', 'hint', 'something'), 1),
#  (('hint', 'something', 'bigger'), 1),
#  (('something', 'bigger', 'tease'), 1),
#  (('bigger', 'tease', 'midway'), 1),
#  (('tease', 'midway', 'credits'), 1),
#  (('midway', 'credits', 'actually'), 1),
#  (('credits', 'actually', 'almost'), 1),
#  (('actually', 'almost', 'beginning'), 1),
#  (('almost', 'beginning', 'honest'), 1),
#  (('beginning', 'honest', 'sit'), 1),
#  (('honest', 'sit', 'back'), 1),
#  (('sit', 'back', 'enhoy'), 1),
#  (('back', 'enhoy', 'movie'), 1),
#  (('enhoy', 'movie', 'really'), 1),
#  (('movie', 'really', 'funny'), 1),
#  (('really', 'funny', 'characters'), 1),
#  (('funny', 'characters', 'quite'), 1),
#  (('characters', 'quite', 'familiar'), 1),
#  (('quite', 'familiar', 'faces'), 1),
#  (('familiar', 'faces', 'some'), 1),
#  (('faces', 'some', 'mcu'), 1),
#  (('some', 'mcu', 'previous'), 1),
#  (('mcu', 'previous', 'entries'), 1),
#  (('previous', 'entries', 'also'), 1),
#  (('entries', 'also', 'asian'), 1),
#  (('also', 'asian', 'cinema'), 1),
#  (('asian', 'cinema', 'well'), 1),
#  (('cinema', 'well', 'done'), 1),
#  (('done', 'i', 'expecting'), 1),
#  (('expecting', 'i', 'visions'), 1),
#  (('i', 'visions', 'film'), 1),
#  (('visions', 'film', 'along'), 1),
#  (('film', 'along', 'lines'), 1),
#  (('along', 'lines', 'snake'), 1),
#  (('lines', 'snake', 'eyes'), 1),
#  (('snake', 'eyes', 'date'), 1),
#  (('eyes', 'date', 'bagel'), 1),
#  (('date', 'bagel', 'four'), 1),
#  (('bagel', 'four', 'course'), 1),
#  (('four', 'course', 'banquet'), 1),
#  (('course', 'banquet', 'fast'), 1),
#  (('banquet', 'fast', 'paced'), 1),
#  (('fast', 'paced', 'energetic'), 1),
#  (('paced', 'energetic', 'relentless'), 1),
#  (('energetic', 'relentless', 'particularly'), 1),
#  (('relentless', 'particularly', 'genre'), 1),
#  (('particularly', 'genre', 'i'), 1),
#  (('genre', 'i', 'normally'), 1),
#  (('i', 'normally', 'go'), 1),
#  (('normally', 'go', 'enjoy'), 1),
#  (('go', 'enjoy', 'i'), 1),
#  (('enjoy', 'i', 'loved'), 1),
#  (('i', 'loved', 'every'), 1),
#  (('loved', 'every', 'second'), 1),
#  (('every', 'second', 'visual'), 1),
#  (('second', 'visual', 'masterpiece'), 1),
#  (('visual', 'masterpiece', 'superb'), 1),
#  (('masterpiece', 'superb', 'acting'), 1),
#  (('superb', 'acting', 'terrific'), 1),
#  (('acting', 'terrific', 'musics'), 1),
#  (('terrific', 'musics', 'produced'), 1),
#  (('musics', 'produced', 'magical'), 1),
#  (('produced', 'magical', 'way'), 1),
#  (('magical', 'way', 'stunning'), 1),
#  (('way', 'stunning', 'i'), 1),
#  (('stunning', 'i', 'plan'), 1),
#  (('i', 'plan', 'seeing'), 1),
#  (('plan', 'seeing', 'understand'), 1),
#  (('seeing', 'understand', 'bits'), 1),
#  (('understand', 'bits', 'little'), 1),
#  (('bits', 'little', 'go'), 1),
#  (('little', 'go', 'watch'), 1),
#  (('go', 'watch', 'love'), 1),
#  (('watch', 'love', 'i'), 1),
#  (('love', 'i', 'find'), 1),
#  (('i', 'find', 'film'), 1),
#  (('find', 'film', 'engaging'), 1),
#  (('film', 'engaging', 'start'), 1),
#  (('engaging', 'start', 'finish'), 1),
#  (('finish', 'i', 'get'), 1),
#  (('i', 'get', 'eyes'), 1),
#  (('get', 'eyes', 'screen'), 1),
#  (('eyes', 'screen', 'the'), 1),
#  (('screen', 'the', 'kung'), 1),
#  (('the', 'kung', 'fu'), 1),
#  (('kung', 'fu', 'good'), 1),
#  (('fu', 'good', 'visual'), 1),
#  (('good', 'visual', 'effects'), 1),
#  (('visual', 'effects', 'wonderful'), 1),
#  (('effects', 'wonderful', 'i'), 1),
#  (('wonderful', 'i', 'enjoyed'), 1),
#  (('i', 'enjoyed', 'every'), 1),
#  (('enjoyed', 'every', 'second'), 1),
#  (('every', 'second', 'film'), 1),
#  (('second', 'film', 'having'), 1),
#  (('film', 'having', 'enjoyed'), 1),
#  (('having', 'enjoyed', 'series'), 1),
#  (('enjoyed', 'series', 'wong'), 1),
#  (('series', 'wong', 'kar'), 1),
#  (('wong', 'kar', 'wei'), 1),
#  (('kar', 'wei', 'films'), 1),
#  (('wei', 'films', 'great'), 1),
#  (('films', 'great', 'see'), 1),
#  (('great', 'see', 'star'), 1),
#  (('see', 'star', 'many'), 1),
#  (('star', 'many', 'classic'), 1),
#  (('many', 'classic', 'features'), 1),
#  (('classic', 'features', 'tony'), 1),
#  (('features', 'tony', 'leung'), 1),
#  (('tony', 'leung', 'feature'), 1),
#  (('leung', 'feature', 'superior'), 1),
#  (('feature', 'superior', 'fantasy'), 1),
#  (('superior', 'fantasy', 'adventure'), 1),
#  (('fantasy', 'adventure', 'he'), 1),
#  (('adventure', 'he', 'man'), 1),
#  (('he', 'man', 'magical'), 1),
#  (('man', 'magical', 'powerful'), 1),
#  (('magical', 'powerful', 'ten'), 1),
#  (('ten', 'rings', 'two'), 1),
#  (('rings', 'two', 'estranged'), 1),
#  (('two', 'estranged', 'children'), 1),
#  (('estranged', 'children', 'it'), 1),
#  (('children', 'it', 'son'), 1),
#  (('it', 'son', 'shaun'), 1),
#  (('son', 'shaun', 'simu'), 1),
#  (('simu', 'liu', 'lively'), 1),
#  (('liu', 'lively', 'altercation'), 1),
#  (('lively', 'altercation', 'heavies'), 1),
#  (('altercation', 'heavies', 'san'), 1),
#  (('heavies', 'san', 'francisco'), 1),
#  (('francisco', 'bus', 'realises'), 1),
#  (('bus', 'realises', 'impending'), 1),
#  (('realises', 'impending', 'danger'), 1),
#  (('impending', 'danger', 'seeks'), 1),
#  (('danger', 'seeks', 'independently'), 1),
#  (('seeks', 'independently', 'minded'), 1),
#  (('independently', 'minded', 'sister'), 1),
#  (('minded', 'sister', 'know'), 1),
#  (('sister', 'know', 'family'), 1),
#  (('know', 'family', 'somewhat'), 1),
#  (('family', 'somewhat', 'unwillingly'), 1),
#  (('somewhat', 'unwillingly', 'reunited'), 1),
#  (('unwillingly', 'reunited', 'working'), 1),
#  (('reunited', 'working', 'together'), 1),
#  (('working', 'together', 'rescue'), 1),
#  (('together', 'rescue', 'late'), 1),
#  (('rescue', 'late', 'lamented'), 1),
#  (('late', 'lamented', 'mother'), 1),
#  (('lamented', 'mother', 'clutches'), 1),
#  (('mother', 'clutches', 'evil'), 1),
#  (('clutches', 'evil', 'protected'), 1),
#  (('evil', 'protected', 'benign'), 1),
#  (('protected', 'benign', 'society'), 1),
#  (('benign', 'society', 'led'), 1),
#  (('society', 'led', 'michelle'), 1),
#  (('led', 'michelle', 'yeoh'), 1),
#  (('michelle', 'yeoh', 'to'), 1),
#  (('yeoh', 'to', 'honest'), 1),
#  (('to', 'honest', 'story'), 1),
#  (('honest', 'story', 'best'), 1),
#  (('story', 'best', 'actually'), 1),
#  (('best', 'actually', 'little'), 1),
#  (('actually', 'little', 'bit'), 1),
#  (('little', 'bit', 'simple'), 1),
#  (('bit', 'simple', 'predictable'), 1),
#  (('simple', 'predictable', 'that'), 1),
#  (('predictable', 'that', 'said'), 1),
#  (('that', 'said', 'however'), 1),
#  (('said', 'however', 'characterisations'), 1),
#  (('however', 'characterisations', 'engaging'), 1),
#  (('characterisations', 'engaging', 'action'), 1),
#  (('action', 'scenes', 'well'), 1),
#  (('scenes', 'well', 'staged'), 1),
#  (('well', 'staged', 'paced'), 1),
#  (('staged', 'paced', 'there'), 1),
#  (('paced', 'there', 'interesting'), 1),
#  (('there', 'interesting', 'underlying'), 1),
#  (('interesting', 'underlying', 'premiss'), 1),
#  (('underlying', 'premiss', 'resonate'), 1),
#  (('premiss', 'resonate', 'planet'), 1),
#  (('resonate', 'planet', 'appears'), 1),
#  (('planet', 'appears', 'fighting'), 1),
#  (('appears', 'fighting', 'back'), 1),
#  (('fighting', 'back', 'mankind'), 1),
#  (('back', 'mankind', 'accumulated'), 1),
#  (('mankind', 'accumulated', 'indifference'), 1),
#  (('accumulated', 'indifference', 'elysian'), 1),
#  (('indifference', 'elysian', 'utopia'), 1),
#  (('elysian', 'utopia', 'xu'), 1),
#  (('utopia', 'xu', 'wenwu'), 1),
#  (('xu', 'wenwu', 'leung'), 1),
#  (('wenwu', 'leung', 'must'), 1),
#  (('leung', 'must', 'invade'), 1),
#  (('must', 'invade', 'rescue'), 1),
#  (('invade', 'rescue', 'wife'), 1),
#  (('rescue', 'wife', 'symbolic'), 1),
#  (('wife', 'symbolic', 'unspoilt'), 1),
#  (('symbolic', 'unspoilt', 'elements'), 1),
#  (('unspoilt', 'elements', 'planet'), 1),
#  (('elements', 'planet', 'intention'), 1),
#  (('planet', 'intention', 'rolling'), 1),
#  (('intention', 'rolling', 'peaceably'), 1),
#  (('rolling', 'peaceably', 'whilst'), 1),
#  (('peaceably', 'whilst', 'impose'), 1),
#  (('whilst', 'impose', 'the'), 1),
#  (('impose', 'the', 'production'), 1),
#  (('the', 'production', 'standards'), 1),
#  (('production', 'standards', 'typically'), 1),
#  (('standards', 'typically', 'high'), 1),
#  (('typically', 'high', 'plenty'), 1),
#  (('high', 'plenty', 'cute'), 1),
#  (('plenty', 'cute', 'dangerous'), 1),
#  (('cute', 'dangerous', 'beasties'), 1),
#  (('dangerous', 'beasties', 'suit'), 1),
#  (('beasties', 'suit', 'please'), 1),
#  (('suit', 'please', 'ages'), 1),
#  (('please', 'ages', 'there'), 1),
#  (('ages', 'there', 'also'), 1),
#  (('also', 'quite', 'fun'), 1),
#  (('quite', 'fun', 'series'), 1),
#  (('fun', 'series', 'scenes'), 1),
#  (('series', 'scenes', 'sir'), 1),
#  (('scenes', 'sir', 'ben'), 1),
#  (('sir', 'ben', 'kingsley'), 1),
#  (('ben', 'kingsley', 'liverpudlian'), 1),
#  (('kingsley', 'liverpudlian', 'poet'), 1),
#  (('liverpudlian', 'poet', 'maybe'), 1),
#  (('poet', 'maybe', 'accent'), 1),
#  (('maybe', 'accent', 'best'), 1),
#  (('accent', 'best', 'stylishly'), 1),
#  (('best', 'stylishly', 'crafted'), 1),
#  (('stylishly', 'crafted', 'finale'), 1),
#  (('crafted', 'finale', 'all'), 1),
#  (('finale', 'all', 'told'), 1),
#  (('all', 'told', 'thoroughly'), 1),
#  (('told', 'thoroughly', 'entertaining'), 1),
#  (('thoroughly', 'entertaining', 'watch'), 1),
#  (('entertaining', 'watch', 'two'), 1),
#  (('watch', 'two', 'hours'), 1),
#  (('two', 'hours', 'flies'), 1),
#  (('hours', 'flies', 'it'), 1),
#  (('flies', 'it', 'ten'), 1),
#  (('it', 'ten', 'years'), 1),
#  (('ten', 'years', 'since'), 1),
#  (('years', 'since', 'shang'), 1),
#  (('since', 'shang', 'chi'), 1),
#  (('chi', 'liu', 'charming'), 1),
#  (('liu', 'charming', 'stoic'), 1),
#  (('charming', 'stoic', 'last'), 1),
#  (('stoic', 'last', 'saw'), 1),
#  (('last', 'saw', 'father'), 1),
#  (('saw', 'father', 'leader'), 1),
#  (('father', 'leader', 'criminal'), 1),
#  (('leader', 'criminal', 'empire'), 1),
#  (('criminal', 'empire', 'the'), 1),
#  (('empire', 'the', 'ten'), 1),
#  (('ten', 'rings', 'wenwu'), 1),
#  (('rings', 'wenwu', 'leung'), 1),
#  (('wenwu', 'leung', 'charismatic'), 1),
#  (('leung', 'charismatic', 'enough'), 1),
#  (('charismatic', 'enough', 'feel'), 1),
#  (('enough', 'feel', 'lot'), 1),
#  (('feel', 'lot', 'empathy'), 1),
#  (('lot', 'empathy', 'even'), 1),
#  (('empathy', 'even', 'terrible'), 1),
#  (('even', 'terrible', 'things'), 1),
#  (('terrible', 'things', 'desperately'), 1),
#  (('things', 'desperately', 'want'), 1),
#  (('desperately', 'want', 'stop'), 1),
#  (('want', 'stop', 'that'), 1),
#  (('stop', 'that', 'also'), 1),
#  (('that', 'also', 'last'), 1),
#  (('also', 'last', 'spent'), 1),
#  (('last', 'spent', 'time'), 1),
#  (('spent', 'time', 'sister'), 1),
#  (('time', 'sister', 'xialing'), 1),
#  (('sister', 'xialing', 'zhang'), 1),
#  (('xialing', 'zhang', 'badass'), 1),
#  (('zhang', 'badass', 'deserves'), 1),
#  (('badass', 'deserves', 'screen'), 1),
#  (('deserves', 'screen', 'time'), 1),
#  (('screen', 'time', 'honestly'), 1),
#  (('time', 'honestly', 'i'), 1),
#  (('honestly', 'i', 'surprised'), 1),
#  (('i', 'surprised', 'future'), 1),
#  (('surprised', 'future', 'projects'), 1),
#  (('future', 'projects', 'he'), 1),
#  (('projects', 'he', 'joined'), 1),
#  (('he', 'joined', 'friend'), 1),
#  (('joined', 'friend', 'katy'), 1),
#  (('katy', 'awkwafina', 'quirky'), 1),
#  (('awkwafina', 'quirky', 'providing'), 1),
#  (('quirky', 'providing', 'lot'), 1),
#  (('providing', 'lot', 'comic'), 1),
#  (('lot', 'comic', 'relief'), 1),
#  (('comic', 'relief', 'something'), 1),
#  (('relief', 'something', 'i'), 1),
#  (('something', 'i', 'told'), 1),
#  (('i', 'told', 'general'), 1),
#  (('told', 'general', 'adept'), 1),
#  (('general', 'adept', 'best'), 1),
#  (('adept', 'best', 'described'), 1),
#  (('best', 'described', 'tense'), 1),
#  (('described', 'tense', 'reunion'), 1),
#  (('tense', 'reunion', 'allows'), 1),
#  (('reunion', 'allows', 'movie'), 1),
#  (('allows', 'movie', 'really'), 1),
#  (('movie', 'really', 'mine'), 1),
#  (('really', 'mine', 'family'), 1),
#  (('mine', 'family', 'melodrama'), 1),
#  (('family', 'melodrama', 'one'), 1),
#  (('melodrama', 'one', 'best'), 1),
#  (('one', 'best', 'elements'), 1),
#  (('best', 'elements', 'i'), 1),
#  (('elements', 'i', 'give'), 1),
#  (('i', 'give', 'away'), 1),
#  (('give', 'away', 'exactly'), 1),
#  (('away', 'exactly', 'antagonist'), 1),
#  (('exactly', 'antagonist', 'intends'), 1),
#  (('antagonist', 'intends', 'hero'), 1),
#  (('intends', 'hero', 'stop'), 1),
#  (('hero', 'stop', 'however'), 1),
#  (('stop', 'however', 'figure'), 1),
#  (('however', 'figure', 'maybe'), 1),
#  (('figure', 'maybe', 'even'), 1),
#  (('maybe', 'even', 'even'), 1),
#  (('even', 'even', 'possible'), 1),
#  (('even', 'possible', 'not'), 1),
#  (('possible', 'not', 'quite'), 1),
#  (('not', 'quite', 'yet'), 1),
#  (('quite', 'yet', 'almost'), 1),
#  (('yet', 'almost', 'black'), 1),
#  (('almost', 'black', 'panther'), 1),
#  (('black', 'panther', 'asian'), 1),
#  (('panther', 'asian', 'audiences'), 1),
#  (('asian', 'audiences', 'lot'), 1),
#  (('audiences', 'lot', 'representation'), 1),
#  (('lot', 'representation', 'including'), 1),
#  (('representation', 'including', 'women'), 1),
#  (('including', 'women', 'some'), 1),
#  (('women', 'some', 'best'), 1),
#  (('some', 'best', 'characters'), 1),
#  (('best', 'characters', 'female'), 1),
#  (('characters', 'female', 'in'), 1),
#  (('female', 'in', 'addition'), 1),
#  (('in', 'addition', 'two'), 1),
#  (('addition', 'two', 'i'), 1),
#  (('two', 'i', 'already'), 1),
#  (('i', 'already', 'mentioned'), 1),
#  (('already', 'mentioned', 'also'), 1),
#  (('mentioned', 'also', 'ying'), 1),
#  (('also', 'ying', 'nan'), 1),
#  (('ying', 'nan', 'yeoh'), 1),
#  (('nan', 'yeoh', 'wise'), 1),
#  (('yeoh', 'wise', 'positively'), 1),
#  (('wise', 'positively', 'drenched'), 1),
#  (('positively', 'drenched', 'chinese'), 1),
#  (('drenched', 'chinese', 'culture'), 1),
#  (('chinese', 'culture', 'third'), 1),
#  (('culture', 'third', 'act'), 1),
#  (('third', 'act', 'ways'), 1),
#  (('act', 'ways', 'feels'), 1),
#  (('ways', 'feels', 'like'), 1),
#  (('feels', 'like', 'belongs'), 1),
#  (('like', 'belongs', 'completely'), 1),
#  (('belongs', 'completely', 'different'), 1),
#  (('completely', 'different', 'film'), 1),
#  (('different', 'film', 'first'), 1),
#  (('film', 'first', 'two'), 1),
#  (('first', 'two', 'takes'), 1),
#  (('two', 'takes', 'especially'), 1),
#  (('takes', 'especially', 'deep'), 1),
#  (('especially', 'deep', 'dive'), 1),
#  (('deep', 'dive', 'ultimately'), 1),
#  (('dive', 'ultimately', 'presented'), 1),
#  (('ultimately', 'presented', 'western'), 1),
#  (('presented', 'western', 'lens'), 1),
#  (('western', 'lens', 'clearly'), 1),
#  (('lens', 'clearly', 'need'), 1),
#  (('clearly', 'need', 'go'), 1),
#  (('need', 'go', 'direction'), 1),
#  (('go', 'direction', 'still'), 1),
#  (('direction', 'still', 'big'), 1),
#  (('still', 'big', 'deal'), 1),
#  (('big', 'deal', 'put'), 1),
#  (('deal', 'put', 'much'), 1),
#  (('put', 'much', 'estimated'), 1),
#  (('much', 'estimated', 'million'), 1),
#  (('estimated', 'million', 'major'), 1),
#  (('million', 'major', 'blockbuster'), 1),
#  (('major', 'blockbuster', 'seen'), 1),
#  (('blockbuster', 'seen', 'millions'), 1),
#  (('seen', 'millions', 'people'), 1),
#  (('millions', 'people', 'would'), 1),
#  (('people', 'would', 'never'), 1),
#  (('would', 'never', 'consider'), 1),
#  (('never', 'consider', 'watching'), 1),
#  (('consider', 'watching', 'art'), 1),
#  (('watching', 'art', 'picture'), 1),
#  (('art', 'picture', 'especially'), 1),
#  (('picture', 'especially', 'one'), 1),
#  (('especially', 'one', 'focusing'), 1),
#  (('one', 'focusing', 'group'), 1),
#  (('focusing', 'group', 'belong'), 1),
#  (('group', 'belong', 'point'), 1),
#  (('belong', 'point', 'countless'), 1),
#  (('point', 'countless', 'times'), 1),
#  (('countless', 'times', 'makes'), 1),
#  (('times', 'makes', 'sense'), 1),
#  (('makes', 'sense', 'major'), 1),
#  (('sense', 'major', 'characters'), 1),
#  (('major', 'characters', 'speak'), 1),
#  (('characters', 'speak', 'mandarin'), 1),
#  (('speak', 'mandarin', 'rather'), 1),
#  (('mandarin', 'rather', 'english'), 1),
#  (('rather', 'english', 'subtitled'), 1),
#  (('english', 'subtitled', 'and'), 1),
#  (('subtitled', 'and', 'worry'), 1),
#  (('and', 'worry', 'think'), 1),
#  (('worry', 'think', 'following'), 1),
#  (('think', 'following', 'important'), 1),
#  (('following', 'important', 'white'), 1),
#  (('important', 'white', 'people'), 1),
#  (('white', 'people', 'screen'), 1),
#  (('people', 'screen', 'made'), 1),
#  (('screen', 'made', 'less'), 1),
#  (('made', 'less', 'the'), 1),
#  (('less', 'the', 'action'), 1),
#  (('the', 'action', 'sequence'), 1),
#  (('action', 'sequence', 'feels'), 1),
#  (('sequence', 'feels', 'distinct'), 1),
#  (('feels', 'distinct', 'belongs'), 1),
#  (('distinct', 'belongs', 'rest'), 1),
#  (('belongs', 'rest', 'memorable'), 1),
#  (('rest', 'memorable', 'pays'), 1),
#  (('memorable', 'pays', 'tribute'), 1),
#  (('pays', 'tribute', 'many'), 1),
#  (('tribute', 'many', 'different'), 1),
#  (('many', 'different', 'kinds'), 1),
#  (('different', 'kinds', 'martial'), 1),
#  (('kinds', 'martial', 'arts'), 1),
#  (('arts', 'films', 'acknowledging'), 1),
#  (('films', 'acknowledging', 'standing'), 1),
#  (('acknowledging', 'standing', 'shoulders'), 1),
#  (('standing', 'shoulders', 'giants'), 1),
#  (('shoulders', 'giants', 'jackie'), 1),
#  (('giants', 'jackie', 'chan'), 1),
#  (('jackie', 'chan', 'wuxia'), 1),
#  (('chan', 'wuxia', 'etc'), 1),
#  (('wuxia', 'etc', 'the'), 1),
#  (('etc', 'the', 'choreography'), 1),
#  (('the', 'choreography', 'matched'), 1),
#  (('choreography', 'matched', 'skill'), 1),
#  (('matched', 'skill', 'cinematography'), 1),
#  (('skill', 'cinematography', 'not'), 1),
#  (('cinematography', 'not', 'seeing'), 1),
#  (('not', 'seeing', 'incredible'), 1),
#  (('seeing', 'incredible', 'fighting'), 1),
#  (('incredible', 'fighting', 'camera'), 1),
#  (('fighting', 'camera', 'dynamic'), 1),
#  (('camera', 'dynamic', 'celebrating'), 1),
#  (('dynamic', 'celebrating', 'highlighting'), 1),
#  (('celebrating', 'highlighting', 'incredible'), 1),
#  (('highlighting', 'incredible', 'that'), 1),
#  (('incredible', 'that', 'hire'), 1),
#  (('that', 'hire', 'bill'), 1),
#  (('hire', 'bill', 'pope'), 1),
#  (('bill', 'pope', 'director'), 1),
#  (('pope', 'director', 'photography'), 1),
#  (('director', 'photography', 'matrix'), 1),
#  (('photography', 'matrix', 'trilogy'), 1),
#  (('matrix', 'trilogy', 'two'), 1),
#  (('trilogy', 'two', 'sam'), 1),
#  (('two', 'sam', 'raimi'), 1),
#  (('sam', 'raimi', 'spider'), 1),
#  (('raimi', 'spider', 'man'), 1),
#  (('spider', 'man', 'entries'), 1),
#  (('man', 'entries', 'darkman'), 1),
#  (('entries', 'darkman', 'team'), 1),
#  (('darkman', 'team', 'america'), 1),
#  (('team', 'america', 'the'), 1),
#  (('america', 'the', 'special'), 1),
#  (('special', 'effects', 'excellent'), 1),
#  (('effects', 'excellent', 'there'), 1),
#  (('excellent', 'there', 'issues'), 1),
#  (('there', 'issues', 'pacing'), 1),
#  (('issues', 'pacing', 'certainly'), 1),
#  (('pacing', 'certainly', 'chunk'), 1),
#  (('certainly', 'chunk', 'composed'), 1),
#  (('chunk', 'composed', 'almost'), 1),
#  (('composed', 'almost', 'entirely'), 1),
#  (('almost', 'entirely', 'flashbacks'), 1),
#  (('entirely', 'flashbacks', 'this'), 1),
#  (('flashbacks', 'this', 'features'), 1),
#  (('this', 'features', 'relatively'), 1),
#  (('features', 'relatively', 'brief'), 1),
#  (('relatively', 'brief', 'highly'), 1),
#  (('brief', 'highly', 'concentrated'), 1),
#  (('highly', 'concentrated', 'surprisingly'), 1),
#  (('concentrated', 'surprisingly', 'graphic'), 1),
#  (('surprisingly', 'graphic', 'gore'), 1),
#  (('graphic', 'gore', 'know'), 1),
#  (('gore', 'know', 'time'), 1),
#  (('know', 'time', 'fact'), 1),
#  (('time', 'fact', 'happening'), 1),
#  (('fact', 'happening', 'beings'), 1),
#  (('happening', 'beings', 'clearly'), 1),
#  (('beings', 'clearly', 'human'), 1),
#  (('clearly', 'human', 'enough'), 1),
#  (('human', 'enough', 'get'), 1),
#  (('enough', 'get', 'away'), 1),
#  (('get', 'away', 'kind'), 1),
#  (('away', 'kind', 'thing'), 1),
#  (('kind', 'thing', 'pg'), 1),
#  (('thing', 'pg', 'rating'), 1),
#  (('pg', 'rating', 'pepperidge'), 1),
#  (('rating', 'pepperidge', 'farm'), 1),
#  (('pepperidge', 'farm', 'remembers'), 1),
#  (('farm', 'remembers', 'well'), 1),
#  (('remembers', 'well', 'little'), 1),
#  (('well', 'little', 'strong'), 1),
#  (('little', 'strong', 'language'), 1),
#  (('strong', 'language', 'i'), 1),
#  (('language', 'i', 'recommend'), 1),
#  (('i', 'recommend', 'fan'), 1),
#  ...]

# %%
freq_dis = nltk.FreqDist(nltk.bigrams(looping))
freq_dict = dict(freq_dis)
for bi_gram in freq_dis:
  print(str(bi_gram) + '-' + str(freq_dict[bi_gram] / afterlooping.count(bi_gram[1])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e81a254609fc> in <module>
# ----> 1 freq_dis = nltk.FreqDist(nltk.bigrams(looping))
#       2 freq_dict = dict(freq_dis)
#       3 for bi_gram in freq_dis:
#       4   print(str(bi_gram) + '-' + str(freq_dict[bi_gram] / afterlooping.count(bi_gram[1])))
#
# NameError: name 'nltk' is not defined

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet31 to /root/nltk_data...
#        |   Unzipping corpora/wordnet31.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
whole_dataset = ''
index = []
i = 1
for line in df['Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freqk = []
  for line in df['Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#             o f c o u r s e i r i f f i n g t e  ...  r s f o r t h e t e n r i n g s
# Review-1                                    0.0  ...                              0.0
# Review-2                                    0.0  ...                              0.0
# Review-3                                    0.0  ...                              0.0
# Review-4                                    1.0  ...                              0.0
# Review-5                                    0.0  ...                              0.0
# ...                                         ...  ...                              ...
# Review-121                                  0.0  ...                              0.0
# Review-122                                  0.0  ...                              0.0
# Review-123                                  0.0  ...                              0.0
# Review-124                                  0.0  ...                              0.0
# Review-125                                  0.0  ...                              1.0
#
# [125 rows x 6442 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
#1)documents-terms weights

import math
no_of_sentences = final_df["Lower casing"].values.tolist()
no_of_words = set([j for i in sentences for j in i.split(" ")])
tf_idf_df = pd.DataFrame(words, columns=["words"])
count=1
def tf_idf(x,sentence):
  value_1 = sentence.count(x)
  size_1 = len(sentence.split(" "))
  if(value != 0):
    return (value/size)*(math.log(size/value, 10))
  else:
    return 0
for sentence in sentences:
  tf_idf_df["Review"+str(count)] = tf_idf_df["no_of_words"].apply(lambda x: tf_idf(x,sentence))
  count=count+1
tf_idf_df
# Out:
#             words  Review1  Review2  ...  Review123  Review124  Review125
# 0                      0.0      0.0  ...  -5.542116        0.0  -4.156099
# 1          planet      0.0      0.0  ...   0.000000        0.0   0.000000
# 2          nature      0.0      0.0  ...   0.000000        0.0   0.000000
# 3        opponent      0.0      0.0  ...   0.000000        0.0   0.000000
# 4           score      0.0      0.0  ...   0.000000        0.0   0.000000
# ...           ...      ...      ...  ...        ...        ...        ...
# 3619     pounding      0.0      0.0  ...   0.000000        0.0   0.000000
# 3620      eastern      0.0      0.0  ...   0.000000        0.0   0.000000
# 3621     products      0.0      0.0  ...   0.000000        0.0   0.000000
# 3622  seriousness      0.0      0.0  ...   0.000000        0.0   0.000000
# 3623        ahead      0.0      0.0  ...   0.000000        0.0   0.000000
#
# [3624 rows x 126 columns]

# %%
#2)cosine similariity

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
X_Value = "text directly (rather than e.g. titles and abstracts), and suggests appropriate approaches to doing this, with a focus on the role of natural language processing. The paper also comments on possible connections with data and knowledge retrieval, and concludes by emphasizing the importance of rigorous"
X_after_tokens = word_tokenize(X_Value)
stop = stopwords.words('english') 
X_after_stop_words = {word for word in X_after_tokens if not word in stop}
def cosine_value(X_after_stop_words, Y_after_stop_words):
  cosine = 0
  list1 = []
  list2 = []
  rvector = X_after_stop_words.union(Y_after_stop_words)  
  for w in rvector: 
    if w in X_after_stop_words: list1.append(1)
    else: list1.append(0) 
    if w in X_after_stop_words: list2.append(1) 
    else: list2.append(0) 
  for i in range(len(rvector)): 
    cosine += list1[i]*list2[i] 
  cv = cosine / float((sum(list1)*sum(list2))**0.5)
  return cv
cosine_similarity = []
for i in df['Lower casing']:
  Y_after_tokens = word_tokenize(i)
  Y_after_stop_words = {word for word in Y_after_tokens if not word in stop}
  cosine_similarity.append(cosine_value(X_after_stop_words, Y_after_stop_words))
cs_df = pd.DataFrame(list(zip(df['Lower casing'], cosine_similarity)), columns = ['Abstracts', 'Cosine Similarity'])
cs_df
# Out:
#                                              Abstracts  Cosine Similarity
# 0                                                                     1.0
# 1                                                                     1.0
# 2                                                                     1.0
# 3    of course i riffing teasing making fun certain...                1.0
# 4    i expecting i visions film along lines snake e...                1.0
# ..                                                 ...                ...
# 120  unlogical story plot luckily actors performanc...                1.0
# 121  marvel back root one perfect film hell lot ent...                1.0
# 122  usually mcu movies forgotten soon i exit theat...                1.0
# 123                                                                   1.0
# 124  the cinema was on fire i think it partly katy ...                1.0
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/

# %%
pip install --upgrade gensim
# Out:
# Requirement already satisfied: gensim in c:\users\admin\anaconda3\lib\site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\admin\anaconda3\lib\site-packages (from gensim) (1.20.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\admin\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: Cython==0.29.23 in c:\users\admin\anaconda3\lib\site-packages (from gensim) (0.29.23)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\admin\anaconda3\lib\site-packages (from gensim) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
sentences = ...
modelname = word2vec(sentences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1ec0a6d2daa9> in <module>
#       1 sentences = ...
# ----> 2 modelname = word2vec(sentences)
#
# NameError: name 'word2vec' is not defined

# %%
print(modelname['word'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e6f169698c28> in <module>
# ----> 1 print(modelname['word'])
#
# NameError: name 'modelname' is not defined

# %%
modelname.wv.save_word2vec_format('model.bin')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2a7bfc7dea48> in <module>
# ----> 1 modelname.wv.save_word2vec_format('model.bin')
#
# NameError: name 'modelname' is not defined

# %%
modelname.wv.save_word2vec_format('modelname.txt', binary=False
                                  
model = Word2Vec.load('model.bin')

# %%
from gensim.models import Word2Vec
# define training data
noofsentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
modelname = Word2Vec(sentences, min_count=1)
# summarize the loaded model
print(modelname)
# summarize vocabulary
words = list(modelname.wv.vocab)
print(words)
# access vector for one word
print(modelname['sentence'])
# save model
modelname.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-aeafb3232b3c> in <module>
#       7 			['and', 'the', 'final', 'sentence']]
#       8 # train model
# ----> 9 modelname = Word2Vec(sentences, min_count=1)
#      10 # summarize the loaded model
#      11 print(modelname)
#
# ~\anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     422
#     423         if corpus_iterable is not None or corpus_file is not None:
# --> 424             self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
#     425             self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
#     426             self.train(
#
# ~\anaconda3\lib\site-packages\gensim\models\word2vec.py in _check_corpus_sanity(self, corpus_iterable, corpus_file, passes)
#    1497             raise TypeError("Parameter corpus_file must be a valid path to a file, got %r instead" % corpus_file)
#    1498         if corpus_iterable is not None and not isinstance(corpus_iterable, Iterable):
# -> 1499             raise TypeError(
#    1500                 "The corpus_iterable must be an iterable of lists of strings, got %r instead" % corpus_iterable)
#    1501         if corpus_iterable is not None and isinstance(corpus_iterable, GeneratorType) and passes > 1:
#
# TypeError: The corpus_iterable must be an iterable of lists of strings, got Ellipsis instead

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
https://github.com/goutham-info5731-spring2022/goutham_info5731/blob/main/data%20.csv
